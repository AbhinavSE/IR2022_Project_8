# %%
import pandas as pd

# %%
meta = pd.read_csv("Data/metadata.csv")
meta
# Out:
#                                                 Artist                Album  \
# 0                                        Frank Sinatra   Platinum Selection
# 1                                           Ed Sheeran                    ÷
# 2                                             Dua Lipa             Dua Lipa
# 3                                             Coldplay       Greatest Songs
# 4                                        One Direction         Take Me Home
# ..                                                 ...                  ...
# 371                                   The Chainsmokers    100% Chainsmokers
# 372                                       Taylor Swift           Essentials
# 373                                         Katy Perry       Smile (Deluxe)
# 374  Calum Scott, Dawn Connie Morton-Young, Isaac O...  Only Human (Deluxe)
# 375      {'k', 'n', 'r', ' ', 'i', 's', 'a', 'f', 't'}                  NaN
#
#                         Title            Genre  \
# ...

# %%
meta['Id'] = meta.index

# %%
meta.loc[meta['Artist'] == 'The Beatles', 'image_folder'] = '/image/cover-375.png'
meta.loc[meta['Artist'] == 'Oasis', 'image_folder'] = '/image/cover-376.jpg'

# %%
# Get all the artists in the dataset which do not have a image_folder
meta[meta['image_folder'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Artist, Album, Title, Genre, Comments, music_folder, image_folder, Id]
# Index: []

# %%
meta.fillna('None', inplace=True)

# %%
meta.to_csv("App/assets/data/metadata.csv", index=False)

# %%
meta.isna().sum()
# Out:
# Artist          0
# Album           0
# Title           0
# Genre           0
# Comments        0
# music_folder    0
# image_folder    0
# Id              0
# dtype: int64
